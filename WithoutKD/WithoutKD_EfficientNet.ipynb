# %% [markdown]
# <a href="https://colab.research.google.com/github/mshitie/MS_KD/blob/main/WithoutKD/WithoutKD_EfficientNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rarfile

from google.colab import drive
import rarfile
import os

# Mount Google Drive
drive.mount('/content/drive')

# Path to the .rar file in Google Drive
rar_path = '/content/drive/MyDrive/computer_vision/main_data_croped.rar'

# Destination folder to extract the contents
destination_folder = '/content'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Extract the .rar file
with rarfile.RarFile(rar_path, 'r') as rar_ref:
    rar_ref.extractall(destination_folder)

print("Extraction completed.")
# Out:
# Requirement already satisfied: rarfile in /usr/local/lib/python3.10/dist-packages (4.1)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Extraction completed.

# %%
import os
import cv2
from PIL import Image
import numpy as np
import scipy
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import auc, roc_curve
from tqdm import tqdm

import time
# Out:
# <ipython-input-3-c760a79cdaf2>:8: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# Keras & Tensorflow
import keras
import tensorflow as tf
from keras import layers
from keras.models import Model
from keras.layers import Lambda, concatenate
from tensorflow.keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import GlobalAveragePooling2D , Conv2D , MaxPooling2D
from keras.layers import  Dropout , BatchNormalization , Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import ResNet50
from keras.callbacks import Callback , ReduceLROnPlateau , ModelCheckpoint
from sklearn.metrics import cohen_kappa_score, accuracy_score
from keras.losses import categorical_crossentropy as logloss
from keras.metrics import categorical_accuracy

# %%
# trachoma main dataset binary image classification
import os
import random
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# Set the path to the directory containing the dataset
dataset_dir = '/content/main_data_croped'

# Read the CSV file
data = pd.read_csv(os.path.join(dataset_dir, '/content/drive/MyDrive/computer_vision/tfti2.csv'), usecols=["key", "class"])

# Convert the 'class' column to string
data['class'] = data['class'].astype(str)

# Filter the data to include only classes 1 and 2
data = data[data['class'].isin(['1', '2', '3'])]

# Split the data into training, validation, and testing sets
train_data, test_data = train_test_split(data, test_size=0.2, random_state=0)
valid_data, test_data = train_test_split(test_data, test_size=0.5, random_state=0)

# Print the number of samples in each set
print('Number of train samples:', train_data.shape[0])
print('Number of valid samples:', valid_data.shape[0])
print('Number of test samples:', test_data.shape[0])

# Preprocess data
train_data["key"] = train_data["key"].apply(lambda x: x + ".jpg")
valid_data["key"] = valid_data["key"].apply(lambda x: x + ".jpg")
test_data["key"] = test_data["key"].apply(lambda x: x + ".jpg")

BATCH_SIZE = 16
HEIGHT = 224
WIDTH = 224
N_CLASSES = 3

# Create data generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    shear_range=0.2,
    horizontal_flip=True,
    vertical_flip=True
)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_data,
    directory=dataset_dir,
    x_col="key",
    y_col="class",
    class_mode="categorical",
    batch_size=BATCH_SIZE,
    target_size=(HEIGHT, WIDTH),
    seed=0
)

valid_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    shear_range=0.2,
    horizontal_flip=True,
    vertical_flip=True
)

valid_generator = valid_datagen.flow_from_dataframe(
    dataframe=valid_data,
    directory=dataset_dir,
    x_col="key",
    y_col="class",
    class_mode="categorical",
    batch_size=BATCH_SIZE,
    target_size=(HEIGHT, WIDTH),
    seed=0
)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_data,
    directory=dataset_dir,
    x_col="key",
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
    target_size=(HEIGHT, WIDTH),
    seed=0
)
# Out:
# Number of train samples: 1195
# Number of valid samples: 149
# Number of test samples: 150
# Found 1195 validated image filenames belonging to 3 classes.
# Found 149 validated image filenames belonging to 3 classes.
# Found 150 validated image filenames belonging to 3 classes.

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import layers, regularizers

def eff_model(backbone , lr = 1e-4):
  effmodel = Sequential()
  effmodel.add(backbone)
  effmodel.add(layers.GlobalAveragePooling2D())
  effmodel.add(layers.Dropout(0.5))
  effmodel.add(layers.BatchNormalization())
  effmodel.add(layers.Dense(N_CLASSES, activation='softmax', kernel_regularizer=regularizers.l2(0.01), name='output'))

  effmodel.compile(
        loss='categorical_crossentropy',
        optimizer=Adam(learning_rate=lr),
        metrics=['accuracy']
    )

  return effmodel


EfficientNet = EfficientNetB0(
    weights = 'imagenet',
    include_top = False,
    input_shape =(224 , 224 , 3)
)
#call the model
effmodel = eff_model(EfficientNet , lr = 1e-4)
effmodel.build((None, 224, 224, 3))
effmodel.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 7, 7, 1280)        4049571
#  )
#
#  global_average_pooling2d_1  (None, 1280)              0
#   (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 1280)              0
#
#  batch_normalization_1 (Bat  (None, 1280)              5120
#  chNormalization)
#
#  output (Dense)              (None, 3)                 3843
#
# =================================================================
# Total params: 4058534 (15.48 MB)
# Trainable params: 4013951 (15.31 MB)
# Non-trainable params: 44583 (174.16 KB)
# _________________________________________________________________

# %%
# Training the teacher model with Resnet50
# Train the teacher model as usual
# Learning Rate Scheduling
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, min_lr=1e-7)
epochs = 50
batch_size = 32
teacher_his = effmodel.fit(train_generator,
          batch_size=batch_size,
          epochs=epochs,
          verbose=2,
          validation_data=valid_generator,
                           callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 75/75 - 63s - loss: 1.3503 - accuracy: 0.4720 - val_loss: 1.0471 - val_accuracy: 0.6510 - lr: 1.0000e-04 - 63s/epoch - 838ms/step
# Epoch 2/50
# 75/75 - 24s - loss: 1.1159 - accuracy: 0.5649 - val_loss: 0.9787 - val_accuracy: 0.6510 - lr: 1.0000e-04 - 24s/epoch - 316ms/step
# Epoch 3/50
# 75/75 - 23s - loss: 0.9894 - accuracy: 0.6285 - val_loss: 0.9394 - val_accuracy: 0.6510 - lr: 1.0000e-04 - 23s/epoch - 309ms/step
# Epoch 4/50
# 75/75 - 21s - loss: 0.9232 - accuracy: 0.6661 - val_loss: 1.0262 - val_accuracy: 0.6577 - lr: 1.0000e-04 - 21s/epoch - 285ms/step
# Epoch 5/50
# 75/75 - 23s - loss: 0.8185 - accuracy: 0.7121 - val_loss: 1.0779 - val_accuracy: 0.6577 - lr: 1.0000e-04 - 23s/epoch - 308ms/step
# Epoch 6/50
# 75/75 - 23s - loss: 0.8223 - accuracy: 0.7063 - val_loss: 1.2019 - val_accuracy: 0.6510 - lr: 1.0000e-04 - 23s/epoch - 311ms/step
# Epoch 7/50
# 75/75 - 23s - loss: 0.7398 - accuracy: 0.7607 - val_loss: 0.9552 - val_accuracy: 0.6510 - lr: 1.0000e-04 - 23s/epoch - 306ms/step
# Epoch 8/50
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 75/75 - 22s - loss: 0.6370 - accuracy: 0.7808 - val_loss: 0.9767 - val_accuracy: 0.6443 - lr: 1.0000e-04 - 22s/epoch - 290ms/step
# Epoch 9/50
# 75/75 - 23s - loss: 0.6500 - accuracy: 0.7774 - val_loss: 0.9646 - val_accuracy: 0.6107 - lr: 1.0000e-05 - 23s/epoch - 311ms/step
# Epoch 10/50
# 75/75 - 23s - loss: 0.6109 - accuracy: 0.7983 - val_loss: 1.2491 - val_accuracy: 0.6376 - lr: 1.0000e-05 - 23s/epoch - 307ms/step
# Epoch 11/50
# 75/75 - 25s - loss: 0.6115 - accuracy: 0.7824 - val_loss: 0.8297 - val_accuracy: 0.6980 - lr: 1.0000e-05 - 25s/epoch - 332ms/step
# Epoch 12/50
# 75/75 - 21s - loss: 0.6663 - accuracy: 0.7715 - val_loss: 1.1711 - val_accuracy: 0.5034 - lr: 1.0000e-05 - 21s/epoch - 286ms/step
# Epoch 13/50
# 75/75 - 23s - loss: 0.6494 - accuracy: 0.7715 - val_loss: 0.6285 - val_accuracy: 0.7852 - lr: 1.0000e-05 - 23s/epoch - 308ms/step
# Epoch 14/50
# 75/75 - 22s - loss: 0.5895 - accuracy: 0.8033 - val_loss: 0.6055 - val_accuracy: 0.8054 - lr: 1.0000e-05 - 22s/epoch - 293ms/step
# Epoch 15/50
# 75/75 - 23s - loss: 0.6591 - accuracy: 0.7858 - val_loss: 0.7937 - val_accuracy: 0.7181 - lr: 1.0000e-05 - 23s/epoch - 309ms/step
# Epoch 16/50
# 75/75 - 21s - loss: 0.6179 - accuracy: 0.7874 - val_loss: 0.9539 - val_accuracy: 0.6443 - lr: 1.0000e-05 - 21s/epoch - 284ms/step
# Epoch 17/50
# 75/75 - 24s - loss: 0.6105 - accuracy: 0.7975 - val_loss: 1.2115 - val_accuracy: 0.5034 - lr: 1.0000e-05 - 24s/epoch - 316ms/step
# Epoch 18/50
# 75/75 - 22s - loss: 0.6195 - accuracy: 0.7866 - val_loss: 0.8873 - val_accuracy: 0.6174 - lr: 1.0000e-05 - 22s/epoch - 292ms/step
# Epoch 19/50
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 75/75 - 23s - loss: 0.5688 - accuracy: 0.8117 - val_loss: 0.8789 - val_accuracy: 0.7248 - lr: 1.0000e-05 - 23s/epoch - 301ms/step
# Epoch 20/50
# 75/75 - 23s - loss: 0.5703 - accuracy: 0.8033 - val_loss: 0.9393 - val_accuracy: 0.7047 - lr: 1.0000e-06 - 23s/epoch - 307ms/step
# Epoch 21/50
# 75/75 - 21s - loss: 0.5893 - accuracy: 0.7941 - val_loss: 0.6743 - val_accuracy: 0.7517 - lr: 1.0000e-06 - 21s/epoch - 286ms/step
# Epoch 22/50
# 75/75 - 23s - loss: 0.6332 - accuracy: 0.7891 - val_loss: 0.5915 - val_accuracy: 0.7919 - lr: 1.0000e-06 - 23s/epoch - 308ms/step
# Epoch 23/50
# 75/75 - 22s - loss: 0.6121 - accuracy: 0.7941 - val_loss: 0.4720 - val_accuracy: 0.8255 - lr: 1.0000e-06 - 22s/epoch - 295ms/step
# Epoch 24/50
# 75/75 - 23s - loss: 0.5696 - accuracy: 0.8176 - val_loss: 0.5585 - val_accuracy: 0.8188 - lr: 1.0000e-06 - 23s/epoch - 307ms/step
# Epoch 25/50
# 75/75 - 21s - loss: 0.6012 - accuracy: 0.8025 - val_loss: 0.5226 - val_accuracy: 0.8456 - lr: 1.0000e-06 - 21s/epoch - 286ms/step
# Epoch 26/50
# 75/75 - 24s - loss: 0.5984 - accuracy: 0.8025 - val_loss: 0.6975 - val_accuracy: 0.7651 - lr: 1.0000e-06 - 24s/epoch - 316ms/step
# Epoch 27/50
# 75/75 - 21s - loss: 0.5997 - accuracy: 0.7975 - val_loss: 0.4633 - val_accuracy: 0.8456 - lr: 1.0000e-06 - 21s/epoch - 285ms/step
# Epoch 28/50
# 75/75 - 23s - loss: 0.5950 - accuracy: 0.7933 - val_loss: 0.5386 - val_accuracy: 0.8121 - lr: 1.0000e-06 - 23s/epoch - 307ms/step
# Epoch 29/50
# 75/75 - 25s - loss: 0.5699 - accuracy: 0.8092 - val_loss: 0.4733 - val_accuracy: 0.8523 - lr: 1.0000e-06 - 25s/epoch - 328ms/step
# Epoch 30/50
# 75/75 - 21s - loss: 0.5681 - accuracy: 0.8176 - val_loss: 0.5643 - val_accuracy: 0.8456 - lr: 1.0000e-06 - 21s/epoch - 285ms/step
# Epoch 31/50
# 75/75 - 23s - loss: 0.6272 - accuracy: 0.7900 - val_loss: 0.5130 - val_accuracy: 0.8456 - lr: 1.0000e-06 - 23s/epoch - 308ms/step
# Epoch 32/50
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1e-07.
# 75/75 - 25s - loss: 0.5884 - accuracy: 0.7941 - val_loss: 0.5384 - val_accuracy: 0.8255 - lr: 1.0000e-06 - 25s/epoch - 331ms/step
# Epoch 33/50
# 75/75 - 23s - loss: 0.6471 - accuracy: 0.7749 - val_loss: 0.4233 - val_accuracy: 0.8658 - lr: 1.0000e-07 - 23s/epoch - 309ms/step
# Epoch 34/50
# 75/75 - 24s - loss: 0.6232 - accuracy: 0.7983 - val_loss: 0.5093 - val_accuracy: 0.8591 - lr: 1.0000e-07 - 24s/epoch - 323ms/step
# Epoch 35/50
# 75/75 - 21s - loss: 0.5965 - accuracy: 0.8042 - val_loss: 0.4775 - val_accuracy: 0.8255 - lr: 1.0000e-07 - 21s/epoch - 286ms/step
# Epoch 36/50
# 75/75 - 23s - loss: 0.5444 - accuracy: 0.8084 - val_loss: 0.4785 - val_accuracy: 0.8322 - lr: 1.0000e-07 - 23s/epoch - 307ms/step
# Epoch 37/50
# 75/75 - 22s - loss: 0.5829 - accuracy: 0.7941 - val_loss: 0.4905 - val_accuracy: 0.8591 - lr: 1.0000e-07 - 22s/epoch - 294ms/step
# Epoch 38/50
# 75/75 - 24s - loss: 0.5879 - accuracy: 0.7975 - val_loss: 0.4583 - val_accuracy: 0.8389 - lr: 1.0000e-07 - 24s/epoch - 317ms/step
# Epoch 39/50
# 75/75 - 22s - loss: 0.6000 - accuracy: 0.8042 - val_loss: 0.4871 - val_accuracy: 0.8456 - lr: 1.0000e-07 - 22s/epoch - 294ms/step
# Epoch 40/50
# 75/75 - 24s - loss: 0.5796 - accuracy: 0.8000 - val_loss: 0.4585 - val_accuracy: 0.8456 - lr: 1.0000e-07 - 24s/epoch - 321ms/step
# Epoch 41/50
# 75/75 - 24s - loss: 0.6176 - accuracy: 0.7791 - val_loss: 0.4854 - val_accuracy: 0.8255 - lr: 1.0000e-07 - 24s/epoch - 314ms/step
# Epoch 42/50
# 75/75 - 23s - loss: 0.5931 - accuracy: 0.7967 - val_loss: 0.5353 - val_accuracy: 0.8188 - lr: 1.0000e-07 - 23s/epoch - 311ms/step
# Epoch 43/50
# 75/75 - 22s - loss: 0.5767 - accuracy: 0.8167 - val_loss: 0.5610 - val_accuracy: 0.8591 - lr: 1.0000e-07 - 22s/epoch - 295ms/step
# Epoch 44/50
# 75/75 - 23s - loss: 0.6299 - accuracy: 0.7874 - val_loss: 0.5084 - val_accuracy: 0.8523 - lr: 1.0000e-07 - 23s/epoch - 311ms/step
# Epoch 45/50
# 75/75 - 24s - loss: 0.5962 - accuracy: 0.8084 - val_loss: 0.4812 - val_accuracy: 0.8255 - lr: 1.0000e-07 - 24s/epoch - 316ms/step
# Epoch 46/50
# 75/75 - 24s - loss: 0.5971 - accuracy: 0.8067 - val_loss: 0.4969 - val_accuracy: 0.8523 - lr: 1.0000e-07 - 24s/epoch - 316ms/step
# Epoch 47/50
# 75/75 - 24s - loss: 0.5911 - accuracy: 0.8042 - val_loss: 0.5057 - val_accuracy: 0.8389 - lr: 1.0000e-07 - 24s/epoch - 315ms/step
# Epoch 48/50
# 75/75 - 22s - loss: 0.5776 - accuracy: 0.8042 - val_loss: 0.5072 - val_accuracy: 0.8456 - lr: 1.0000e-07 - 22s/epoch - 290ms/step
# Epoch 49/50
# 75/75 - 24s - loss: 0.6200 - accuracy: 0.7908 - val_loss: 0.4883 - val_accuracy: 0.8255 - lr: 1.0000e-07 - 24s/epoch - 318ms/step
# Epoch 50/50
# 75/75 - 25s - loss: 0.5841 - accuracy: 0.8109 - val_loss: 0.5052 - val_accuracy: 0.8322 - lr: 1.0000e-07 - 25s/epoch - 334ms/step

# %%
#https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/
# summarize history for accuracy
plt.plot(teacher_his.history['accuracy'],)
plt.plot(teacher_his.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
#https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/
# summarize history for accuracy
plt.plot(teacher_his.history['loss'])
plt.plot(teacher_his.history['val_loss'])
plt.title('model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower left')
plt.show()

# %%
# Evaluate the model on the test set
import timeit

start = timeit.default_timer()
test_loss, test_acc = effmodel.evaluate(
    test_generator,
    verbose=0
)

print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
stop = timeit.default_timer()
print('\nTime: ',stop - start,'sec')
# Out:
# Test loss: 0.5114055871963501
# Test accuracy: 0.8333333134651184
#
# Time:  0.6032183639999857 sec

# %%
from sklearn.metrics import classification_report

# Assuming you have a model named 'model_vgg2' and a test generator named 'test_generator'
# Generate predictions for the test data
y_pred = effmodel.predict(test_generator)

# Convert predictions from probabilities to class labels
y_pred_labels = y_pred.argmax(axis=1)

# Get the true labels from the test generator
y_true = test_generator.classes

# Get the class labels
class_labels = list(test_generator.class_indices.keys())

# Generate the classification report
report = classification_report(y_true, y_pred_labels, target_names=class_labels)

# Print the classification report
print(report)
# Out:
# 10/10 [==============================] - 2s 51ms/step
#               precision    recall  f1-score   support
#
#            1       0.86      0.92      0.89       103
#            2       0.74      0.62      0.68        37
#            3       0.78      0.70      0.74        10
#
#     accuracy                           0.83       150
#    macro avg       0.79      0.75      0.77       150
# weighted avg       0.83      0.83      0.83       150
